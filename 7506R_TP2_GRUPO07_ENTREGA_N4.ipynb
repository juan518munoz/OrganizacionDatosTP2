# %% [markdown]
# # Conclusiones
# Realizar las conclusiones correspondientes al trabajo realizado en su totalidad, destacando principalmente los aspectos que consideren más relevantes. Comentar brevemente qué otras opciones hubiesen explorado y quedaron afuera del alcance de este trabajo.

# %% [markdown]
# ## Punto 1

# %% [markdown]
# ### Ampliación del dataset

# %% [markdown]
# El método de Minqing Hu y Bing Liu arrojó una proporción de 30 palabras positivas, y 4 negativas, dentro de las 100 palabras que fueron analizadas. La superioridad de palabras consideradas positivas es esperable debido a que lo que estamos analizando es una descripción de una venta, donde se busca la mayor atracción posible a la hora en que un posible comprador lea la publicación en cuestión. En cuanto a Regex agregamos nuevas columnas indicando cercania a transporte público, y que la propiedad tenga comodities, dos atributos que nos parecen escenciales a la hora de buscar una propiedad, podriamos perfeccionar estas dos categorías creadas reemplazando su valor booleano por una especificación de que transporte o comodity ofrece. Otra alternativa sería crear un atributo para cada transporte en especifico (tiene_tren, tiene_subte, etc) y cada comodity, pero esto agrandaria el tamaño de nuestro dataset, haciendo mas dificil de procesar a la hora de trabajarlo con modelos de machine learning.

# %% [markdown]
# ### Modelos

# %% [markdown]
# Los resultados obtenidos con los hiperparametros viejos comparados con los nuevos son casi identicos y la diferencia de score R2 entre ellos esta dentro del margen de error, los hiperparametros hallados tal vez podrian ser mejores utilizando gridsearchCV en vez de randomsearchCV.

# %% [markdown]
# ## Punto 2

# %% [markdown]
# La red neuronal de clasificación obtuvo un rendimiento aceptable con sus parametros sin optimizar, aunque no logro clasificar bien las propiedades de precio alto, una vez optimizados los hiperparametros la cantidad de verdaderos positivos para la variable precio_alto aumento, asi como tambien decrecio levemente la cantidad de propiedades de este tipo catalogadas como de precio_bajo o precio_medio.

# %% [markdown]
# ## Punto 3

# %% [markdown]
# El segundo ensamble, de stacking, fue armado a partir de tres modelos que no lograron una buena accuracy por su cuenta, destacamos a Gaussian Naive Bayes, cuya accuracy curva ROC se aproximaba a la de un Random Clasifier. El ensamble en si presento una leve mejora respecto a los demas modelos por separado, pero aun asi no logro una performance alta.

# %% [markdown]
# Una manera que pensamos que podria mejorar considerablemente los resultados obtenidos en este punto es haber utilizado mejores modelos de clasificación, como SVC, o no limitar a los utilizados, como Random Forest, usandolo con una cantidad de arboles (de poca altura) baja. Sin embargo estos modelos conllevan una capacidad de computo elevada, requiriendo que el sistema tuviese una mayor memoria ram para poder ser entrenados, y un mejor procesador para que el tiempo de ejecución no sea elevado.
